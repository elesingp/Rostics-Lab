# %%
! pip install hypex
# Out:
# Requirement already satisfied: hypex in c:\python 10\lib\site-packages (0.1.0)
# Requirement already satisfied: tqdm in c:\python 10\lib\site-packages (from hypex) (4.66.2)
# Requirement already satisfied: seaborn<=0.13.2 in c:\python 10\lib\site-packages (from hypex) (0.13.2)
# Requirement already satisfied: faiss-cpu<=1.8.0,>=1.6.0 in c:\python 10\lib\site-packages (from hypex) (1.8.0)
# Requirement already satisfied: scipy<=1.12.0,>=1.5.0 in c:\python 10\lib\site-packages (from hypex) (1.12.0)
# Requirement already satisfied: scikit-learn in c:\python 10\lib\site-packages (from hypex) (1.4.1.post1)
# Requirement already satisfied: statsmodels<=0.14.1 in c:\python 10\lib\site-packages (from hypex) (0.14.1)
# Requirement already satisfied: numpy<=1.26.4,>=1.17.0 in c:\python 10\lib\site-packages (from hypex) (1.26.4)
# Requirement already satisfied: pandas<=2.2.1,>=1.3.5 in c:\python 10\lib\site-packages (from hypex) (2.2.1)
# Requirement already satisfied: matplotlib<=3.8.3,>=3.0.0 in c:\python 10\lib\site-packages (from hypex) (3.8.3)
# Requirement already satisfied: cycler>=0.10 in c:\python 10\lib\site-packages (from matplotlib<=3.8.3,>=3.0.0->hypex) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\gpe9038\appdata\roaming\python\python310\site-packages (from matplotlib<=3.8.3,>=3.0.0->hypex) (24.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gpe9038\appdata\roaming\python\python310\site-packages (from matplotlib<=3.8.3,>=3.0.0->hypex) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python 10\lib\site-packages (from matplotlib<=3.8.3,>=3.0.0->hypex) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python 10\lib\site-packages (from matplotlib<=3.8.3,>=3.0.0->hypex) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python 10\lib\site-packages (from matplotlib<=3.8.3,>=3.0.0->hypex) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\python 10\lib\site-packages (from matplotlib<=3.8.3,>=3.0.0->hypex) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python 10\lib\site-packages (from matplotlib<=3.8.3,>=3.0.0->hypex) (3.1.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python 10\lib\site-packages (from pandas<=2.2.1,>=1.3.5->hypex) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\python 10\lib\site-packages (from pandas<=2.2.1,>=1.3.5->hypex) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\gpe9038\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib<=3.8.3,>=3.0.0->hypex) (1.16.0)
# Requirement already satisfied: patsy>=0.5.4 in c:\python 10\lib\site-packages (from statsmodels<=0.14.1->hypex) (0.5.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\python 10\lib\site-packages (from scikit-learn->hypex) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python 10\lib\site-packages (from scikit-learn->hypex) (3.3.0)
# Requirement already satisfied: colorama in c:\users\gpe9038\appdata\roaming\python\python310\site-packages (from tqdm->hypex) (0.4.6)
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'C:\python 10\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
from hypex import Matcher
# Out:
# C:\Users\gpe9038\AppData\Local\Temp\ipykernel_19796\98879106.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from hypex import Matcher
#
# ModuleNotFoundError: No module named 'hypex'

# %%
data = DataGenerator(na_columns=['feature_3', 'feature_2'],
    num_features=2,
    num_targets=2)
data.df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data = DataGenerator(na_columns=['feature_3', 'feature_2'],
#       2     num_features=2,
#       3     num_targets=2)
#       4 data.df
#
# NameError: name 'DataGenerator' is not defined

# %%
info_col = ['user_id']

outcome = 'post_spends'
treatment = 'treat'

# %%
# Standard model with base parameters
model = Matcher(input_data=df, outcome=outcome, treatment=treatment, info_col=info_col)
# Out:
# [19.03.2024 14:17:26 | hypex | INFO]: Number of NaN values filled with zeros: 446
